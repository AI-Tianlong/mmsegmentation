# %%
import numpy as np
import torch

# %%
gt_sem_map = np.random.randint(0, 20, (10, 10))

# %%
gt_sem_map.shape
# Out:
# (10, 10)

# %%
results = dict(gt_sem_map=gt_sem_map)

# %%
results['gt_sem_map'].shape
# Out:
# (10, 10)

# %%
results['gt_sem_map']=results['gt_sem_map'][None]

# %%
results['gt_sem_map'].shape
# Out:
# (1, 10, 10)
