# %%
import torch

# %%
weight = '../../../work_dirs/part1-多模态-piip3branch-deit-SBL-upernet-1216_640_224-Google-GF2-S2-miou72.54/iter_80000.pth'

# %%
checkpoint = torch.load(weight)

# %%
checkpoint.keys()
# Out:
# dict_keys(['meta', 'state_dict', 'message_hub', 'optimizer', 'param_schedulers'])

# %%
state_dict = checkpoint['state_dict']

# %%
state_dict.keys()
# Out:
# odict_keys(['backbone.w1', 'backbone.w2', 'backbone.w3', 'backbone.branch1.pos_embed', 'backbone.branch1.patch_embed.proj.weight', 'backbone.branch1.patch_embed.proj.bias', 'backbone.branch1.blocks.0.gamma_1', 'backbone.branch1.blocks.0.gamma_2', 'backbone.branch1.blocks.0.norm1.weight', 'backbone.branch1.blocks.0.norm1.bias', 'backbone.branch1.blocks.0.attn.qkv.weight', 'backbone.branch1.blocks.0.attn.qkv.bias', 'backbone.branch1.blocks.0.attn.proj.weight', 'backbone.branch1.blocks.0.attn.proj.bias', 'backbone.branch1.blocks.0.norm2.weight', 'backbone.branch1.blocks.0.norm2.bias', 'backbone.branch1.blocks.0.mlp.fc1.weight', 'backbone.branch1.blocks.0.mlp.fc1.bias', 'backbone.branch1.blocks.0.mlp.fc2.weight', 'backbone.branch1.blocks.0.mlp.fc2.bias', 'backbone.branch1.blocks.1.gamma_1', 'backbone.branch1.blocks.1.gamma_2', 'backbone.branch1.blocks.1.norm1.weight', 'backbone.branch1.blocks.1.norm1.bias', 'backbone.branch1.blocks.1.attn.qkv.weight', 'backbone.branch1.blocks.1.attn.qkv.
# ...

# %%
print(state_dict['backbone.w1']) # 0.7216   # S2
print(state_dict['backbone.w2']) # 0.9177   # GF2
print(state_dict['backbone.w3']) # 0.8114   # Google
# Out:
# tensor(0.7216)
# tensor(0.9177)
# tensor(0.8114)
